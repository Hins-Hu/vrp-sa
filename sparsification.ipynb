# %%
import networkx as nx
import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import random
import pickle
import osmnx as ox
import copy
import json
import os
import glob

# %%
"""
Input
"""
seed = 10
example = 8
num_nodes = 100
num_clients = 10
budget = 2
num_auto = 3
num_non_auto = 3
num_layer = 2

# Write the input to a file
input = ['seed', 'example', 'num_nodes', 'num_clients', 'budget', 'num_auto', 'num_non_auto', 'num_layer']
input_dict = dict(zip(input, [seed, example, num_nodes, num_clients, budget, num_auto, num_non_auto, num_layer]))
path = 'exact-model-'+str(example)
if not os.path.exists(path):
    os.mkdir('exact-model-' + str(example))
with open('exact-model-' +str(example) + '/input.json', 'w') as outfile:
    json.dump(input_dict, outfile)

# %%
"""
Set the seed
"""
random.seed(seed)
np.random.seed(seed)

# %%
"""
Label mapping
"""  


def label_mapping(V):
    old_to_new = {}
    new_to_old = {} 
    index = 0
    for i in V:
        new_to_old[index] = i
        old_to_new[i] = index
        index += 1
    
    return [old_to_new, new_to_old]

# %%
"""
Build a graph
"""

# Read the network data 
G = pickle.load(open("Manhattan_network.p", "rb"))


# Generate the set of nodes of a subgraph by BFS
def graph_generator(G, num_nodes):
    V = list(G.nodes)
    E = list(G.edges)
    s = random.sample(V, 1)[0]

    visited = [s]
    frontier = [s]
    while len(visited) < num_nodes and len(frontier) > 0:
        i = frontier.pop(0)
        for j in G.neighbors(i):
            if j not in visited:
                visited.append(j)
                frontier.append(j)
    
    return visited

tmp_V = graph_generator(G, num_nodes)
G = G.subgraph(tmp_V)


# Extract the strongly connected components
tmp_V = max(nx.strongly_connected_components(G), key = len)
G = G.subgraph(list(tmp_V))
V = list(G.nodes)
E = list(G.edges)

old_to_new, new_to_old = label_mapping(V)

# %%
"""
Set parameters (key control params, as input, are in the first chunk)
"""

## Depots
K = random.sample(V, 1)

## Trucks
num_truck = num_auto + num_non_auto ### The first half are auto trucks
truck = np.arange(num_truck)

truck_range = (np.random.random(len(truck))) * 50 * 1600
truck_capacity = 10

# Fixed cost to dispatch a truck
truck_cost = np.repeat(100, len(truck))


## Clients
D = random.sample(list(set(V) - set(K)), num_clients)

demand = np.random.lognormal(0.1, 1, size=len(D))
demand[demand >= truck_capacity] = truck_capacity


## Time discretization

# The length of time intervals (in minutes)
gran = 1
# The # of operational hours (in hours)
op = 3
# Time span (in seconds)
T = op * 3600

num_interval = int((60 / gran) * op)
Q = np.arange(num_interval)
a = np.arange(0, T, gran * 60)
b = a + gran * 60

## Extra cost for remote control
control_cost = np.repeat(10, num_auto)

# %%
"""
Visualization
"""

# index_K = [i for i in range(len(V)) if V[i] in K]
# index_D = [i for i in range(len(V)) if V[i] in D]
index_auto_E = [i for i in range(len(E)) if G.edges[E[i]]['highway'] == 'primary' or G.edges[E[i]]['highway'] == 'secondary'] 
node_color = ['w' for _ in range(len(V))]
node_size = [15 for _ in range(len(V))]
edge_color = ['#999999' for _ in range(len(E))]
edge_linewidth = [1 for _ in range(len(E))]

for i in K:
    idx = old_to_new[i]
    node_color[idx] = 'b'
    node_size[idx] = 100
for i in D:
    idx = old_to_new[i]
    node_color[idx] = 'r'
    node_size[idx] = 100
for idx in index_auto_E:
    edge_color[idx] = '#00FF00'
    edge_linewidth[idx] = 2

ox.plot_graph(G, node_color = node_color, node_size = node_size, edge_color = edge_color, 
                edge_linewidth = edge_linewidth, figsize = (30, 30), save = True, filepath = 'sparsification-' + str(example) + '/network.png')
# Out:
# /home/zh223/miniconda3/lib/python3.7/site-packages/pyproj/crs/crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /home/zh223/miniconda3/lib/python3.7/site-packages/pyproj/crs/crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# (<Figure size 2160x2160 with 1 Axes>, <AxesSubplot:>)

# %%
"""
Sparsification - step 1 (remove redundant nodes and edges)
"""

for e in E:
    if G.edges[e]['highway'] == 'primary' or G.edges[e]['highway'] == 'secondary':
        G.edges[e]['control_time'] = 0
    else:
        G.edges[e]['control_time'] = G.edges[e]['length']

remaining_edge = []
remaining_node = []
for i in K+D:
    for j in K+D:
        if i == j:
            continue
        p1 = nx.shortest_path(G, i, j, weight = 'length')
        p2 = nx.shortest_path(G, i, j, weight = 'control_time')
        remaining_node += p1
        remaining_node += p2
        for k in range(len(p1)-1):
            remaining_edge.append((p1[k], p1[k+1], 0))
        for k in range(len(p2)-1):
            remaining_edge.append((p2[k], p2[k+1], 0))
remaining_edge = set(remaining_edge)
remaining_node = set(remaining_node)
edge_to_delete = set(E) - remaining_edge

# Remove a set of nodes
#* Comment this line to visualize how many nodes are deleted 
G = G.subgraph(remaining_node)

# Make a copy to unfreeze the graph
G_s = G.copy()
# Remove a set of edges 
G_s.remove_edges_from(edge_to_delete)

E = list(G_s.edges)
V = list(G_s.nodes)

# Relabel
old_to_new, new_to_old = label_mapping(V)
# Out:
# /home/zh223/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   """

# %%
"""
Visualization
"""

# index_K = [i for i in range(len(V)) if V[i] in K]
# index_D = [i for i in range(len(V)) if V[i] in D]
index_auto_E = [i for i in range(len(E)) if G_s.edges[E[i]]['highway'] == 'primary' or G_s.edges[E[i]]['highway'] == 'secondary'] 
node_color = ['w' for _ in range(len(V))]
node_size = [15 for _ in range(len(V))]
edge_color = ['#999999' for _ in range(len(E))]
edge_linewidth = [1 for _ in range(len(E))]

for i in K:
    idx = old_to_new[i]
    node_color[idx] = 'b'
    node_size[idx] = 100
for i in D:
    idx = old_to_new[i]
    node_color[idx] = 'r'
    node_size[idx] = 100
for idx in index_auto_E:
    edge_color[idx] = '#00FF00'
    edge_linewidth[idx] = 2

ox.plot_graph(G_s, node_color = node_color, node_size = node_size, edge_color = edge_color, 
                edge_linewidth = edge_linewidth, figsize = (30, 30), save = True, filepath = 'sparsification-' + str(example) + '/sparsified-1.png')
# Out:
# /home/zh223/miniconda3/lib/python3.7/site-packages/pyproj/crs/crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /home/zh223/miniconda3/lib/python3.7/site-packages/pyproj/crs/crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# (<Figure size 2160x2160 with 1 Axes>, <AxesSubplot:>)

# %%
"""
Sparsification - step 2 (merge edges)
"""

for v in list(set(V) - set(D)):

    succ = list(G_s.successors(v))
    pred = list(G_s.predecessors(v))

    # Merge all one way roads
    if len(succ) == 1 and len(pred) == 1:
        # print(v)
        # print(G_s[pred[0]][v])
        # print("============")

        # Road types
        rt1 = G_s[pred[0]][v][0]['highway']
        rt2 = G_s[v][succ[0]][0]['highway']

        # Road length
        rl1 = G_s[pred[0]][v][0]['length']
        rl2 = G_s[v][succ[0]][0]['length']

        if (rt1 == 'primary' or rt1 == 'secondary') and (rt2 == 'primary' or rt2 == 'secondary'):
            G_s.add_edge(pred[0], succ[0], highway = rt1, length = rl1 + rl2)
            G_s.remove_edge(pred[0], v)
            G_s.remove_edge(v, succ[0])

            #* Comment this line to visualize how many nodes are deleted 
            G_s.remove_node(v)
        
        if (rt1 != 'primary' and rt1 != 'secondary') and (rt2 != 'primary' and rt2 != 'secondary'):
            G_s.add_edge(pred[0], succ[0], highway = rt1, length = rl1 + rl2)
            G_s.remove_edge(pred[0], v)
            G_s.remove_edge(v, succ[0])
            
            #* Comment this line to visualize how many nodes are deleted 
            G_s.remove_node(v)


    elif len(pred) == 2 and set(pred) == set(succ):
        
        # Road types
        rt1 = G_s[pred[0]][v][0]['highway']
        rt2 = G_s[v][pred[1]][0]['highway']

        # Road length
        rl1 = G_s[pred[0]][v][0]['length']
        rl2 = G_s[v][pred[1]][0]['length']

        if (rt1 == 'primary' or rt1 == 'secondary') and (rt2 == 'primary' or rt2 == 'secondary'):
            G_s.add_edge(pred[0], pred[1], highway = rt1, length = rl1 + rl2)
            G_s.add_edge(pred[1], pred[0], highway = rt1, length = rl1 + rl2)
            G_s.remove_edge(pred[0], v)
            G_s.remove_edge(v, pred[0])
            G_s.remove_edge(pred[1], v)
            G_s.remove_edge(v, pred[1])
            G_s.remove_node(v)

        if (rt1 != 'primary' and rt1 != 'secondary') and (rt2 != 'primary' and rt2 != 'secondary'):
            G_s.add_edge(pred[0], pred[1], highway = rt1, length = rl1 + rl2)
            G_s.add_edge(pred[1], pred[0], highway = rt1, length = rl1 + rl2)
            G_s.remove_edge(pred[0], v)
            G_s.remove_edge(v, pred[0])
            G_s.remove_edge(pred[1], v)
            G_s.remove_edge(v, pred[1])
            G_s.remove_node(v)

    else:
        pass

E = list(G_s.edges)
V = list(G_s.nodes)

# Relabel
old_to_new, new_to_old = label_mapping(V)

# %%
"""
Visualization
"""

# index_K = [i for i in range(len(V)) if V[i] in K]
# index_D = [i for i in range(len(V)) if V[i] in D]
index_auto_E = [i for i in range(len(E)) if G_s.edges[E[i]]['highway'] == 'primary' or G_s.edges[E[i]]['highway'] == 'secondary'] 
node_color = ['w' for _ in range(len(V))]
node_size = [15 for _ in range(len(V))]
edge_color = ['#999999' for _ in range(len(E))]
edge_linewidth = [1 for _ in range(len(E))]

for i in K:
    idx = old_to_new[i]
    node_color[idx] = 'b'
    node_size[idx] = 100
for i in D:
    idx = old_to_new[i]
    node_color[idx] = 'r'
    node_size[idx] = 100
for idx in index_auto_E:
    edge_color[idx] = '#00FF00'
    edge_linewidth[idx] = 2

ox.plot_graph(G_s, node_color = node_color, node_size = node_size, edge_color = edge_color, 
                edge_linewidth = edge_linewidth, figsize = (30, 30), save = True, filepath = 'sparsification-' + str(example) + '/sparsified-2.png')
# Out:
# /home/zh223/miniconda3/lib/python3.7/site-packages/pyproj/crs/crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /home/zh223/miniconda3/lib/python3.7/site-packages/pyproj/crs/crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# (<Figure size 2160x2160 with 1 Axes>, <AxesSubplot:>)

# %%
"""
Build the extended graph
"""

G_e = copy.deepcopy(G_s)
D_e = [old_to_new[i] for i in D]
for i in range(num_layer - 1):

    # Duplicate one more layer
    layer = copy.deepcopy(G_s) 
    G_e = nx.disjoint_union(G_e, layer)

    # Add artificial edges of customers 
    for j in D:
        idx_j = old_to_new[j]
        idx_1 = idx_j + i * len(V)
        idx_2 = idx_j + (i+1) * len(V)
        D_e.append(idx_2)
        G_e.add_edge(idx_1, idx_2, length = 0, highway = 'artificial', index = str(idx_1)+'-'+str(idx_2))

# Construct the demand dictionary
demand_dict = dict(zip(D_e, np.tile(demand, num_clients)))

# Construct the 2-D customer vertices
D_e_2d = np.reshape(D_e, (num_layer, len(D)))

# Add artificial edges of the depot
departure = old_to_new[K[0]]
K_e = []
for i in range(num_layer - 1):
    idx_1 = departure + i * len(V)
    idx_2 = departure + (num_layer - 1) * len(V)
    K_e.append(idx_1)
    G_e.add_edge(idx_1, idx_2, length = 0, highway = 'artificial', index = str(idx_1)+'-'+str(idx_2))
arrival = departure + (num_layer - 1) * len(V)
K_e.append(arrival)

# Make new lists of nodes and edges in the extended graph
E_e = list(G_e.edges())
V_e = list(G_e.nodes)


# Mapping for edges
edge_to_no = {}
no_to_edge = {}
index = 0
for e in E_e:
    no_to_edge[index] = e
    edge_to_no[e] = index
    index += 1

# Sanity Check 
counter = 0
for j in range(num_layer - 1):

    tmp_k = old_to_new[K[0]]
    print(G_e[tmp_k + j * len(V)][tmp_k + (num_layer-1) * len(V)])
    print('++++++++++++++++++++++')
    for i in D:
        tmp_i = old_to_new[i]
        print(G_e[tmp_i + j * len(V)][tmp_i + (j+1) * len(V)])
        counter += 1
    print('======================')

print("The size of the extended graph is: ")
print(len(E_e))
print(len(V_e))
# Out:
# {0: {'length': 0, 'highway': 'artificial', 'index': '39-87'}}
# ++++++++++++++++++++++
# {0: {'length': 0, 'highway': 'artificial', 'index': '26-74'}}
# {0: {'length': 0, 'highway': 'artificial', 'index': '35-83'}}
# {0: {'length': 0, 'highway': 'artificial', 'index': '2-50'}}
# {0: {'length': 0, 'highway': 'artificial', 'index': '27-75'}}
# {0: {'length': 0, 'highway': 'artificial', 'index': '24-72'}}
# {0: {'length': 0, 'highway': 'artificial', 'index': '28-76'}}
# {0: {'length': 0, 'highway': 'artificial', 'index': '33-81'}}
# {0: {'length': 0, 'highway': 'artificial', 'index': '44-92'}}
# {0: {'length': 0, 'highway': 'artificial', 'index': '18-66'}}
# {0: {'length': 0, 'highway': 'artificial', 'index': '4-52'}}
# ======================
# The size of the extended graph is:
# 207
# 96

# %%
"""
Cost and travel time
"""


speed = 3.3528 # in meter/second
f1 = 0.8
f2 = 1


for e in E_e:
    e = (e[0], e[1], 0)
    G_e.edges[e]['travel_time'] = G_e.edges[e]['length'] / speed

for e in E_e:
    e = (e[0], e[1], 0)
    if G_e.edges[e]['highway'] == 'artificial':
        G_e.edges[e]['auto_cost'] = 0
        G_e.edges[e]['non_auto_cost'] = 0
    elif G_e.edges[e]['highway'] == 'primary' or G_e.edges[e]['highway'] == 'secondary':
        G_e.edges[e]['auto_cost'] = f1 * G_e.edges[e]['length']
        G_e.edges[e]['non_auto_cost'] = G_e.edges[e]['length']
    else:
        G_e.edges[e]['auto_cost'] = f2 * G_e.edges[e]['length']
        G_e.edges[e]['non_auto_cost'] = G_e.edges[e]['length']

# %%
"""
The MILP Sovler (Sparse Representation)
"""

# Create a new model
model = gp.Model('sparsification')

# Set the file path for logging
path = 'sparsification-' + str(example) + '/sparsification_log.txt'
if os.path.exists(path):
    os.remove(path)
model.Params.LogFile = path

# Parameters tuning for the MIP solver
model.Params.MIPFocus = 3 # Focusing on the phase 2 (getting good quality solutions)
# model.Params.MIPGap = 0.05 # Specify the terminating duality gap

# Create variables
x = model.addMVar((len(E_e), num_truck), vtype=GRB.BINARY)
y = model.addMVar((len(V_e), num_truck), vtype=GRB.BINARY)
t = model.addMVar((len(V_e), num_truck), vtype=GRB.CONTINUOUS)
u = model.addMVar((num_interval, num_auto), vtype=GRB.BINARY)
alpha = model.addMVar((num_interval, len(E_e), num_auto), vtype=GRB.BINARY)
beta = model.addMVar((num_interval, len(E_e), num_auto), vtype=GRB.BINARY)


# Add constraints

## Flow conservation at all nodes (except the depot)
for i in list(set(V_e) - set([departure, arrival])):
    out_no = [edge_to_no[e] for e in list(G_e.out_edges(i))]
    in_no = [edge_to_no[e] for e in list(G_e.in_edges(i))]
    model.addConstrs(sum(x[out_no, m]) == sum(x[in_no, m]) for m in truck)
    model.addConstrs(sum(x[out_no, m]) <= 1 for m in truck)

## Flow conservation at the depot
departure_out = [edge_to_no[e] for e in list(G_e.out_edges(departure))]
arrival_in = [edge_to_no[e] for e in list(G_e.in_edges(arrival))]

model.addConstrs(sum(x[departure_out, m]) == y[departure, m]
                for m in truck)
model.addConstrs(sum(x[arrival_in, m]) == y[arrival, m]
                for m in truck)
model.addConstrs(y[departure, m] == y[arrival, m]
                for m in truck)

## The # of truck used
model.addConstr(sum(y[departure, :]) <= num_truck)


## Allow a vehicle to pass thru a customer without serving it 
for i in D_e:
    i_in = [edge_to_no[e] for e in list(G_e.in_edges(i))]
    model.addConstrs(sum(x[i_in, m]) >= y[i, m] for m in truck)

## Each truck serves only one customer
model.addConstrs(sum(y[i, m] for i in D_e_2d[:, h] for m in truck) == 1 for h in range(len(D)))


## Transition
for i in D_e:
    for j in D_e:
        if G_e.has_edge(i, j) and G_e[i][j][0]['highway'] == 'artificial':
            model.addConstrs(x[edge_to_no[(i, j)], m] == y[i, m] for m in truck)

## Range limit
model.addConstrs(sum(G_e[i][j][0]['length'] * x[edge_to_no[(i, j)], m] for i in V_e for j in V_e if G_e.has_edge(i, j)) <= truck_range[m]
                for m in truck)

## Capacity limit
model.addConstrs(sum(demand_dict[i] * y[i, m] for i in D_e) <= truck_capacity
                for m in truck)
            
# Subtour elimination + time tracking
for i in V_e:
    for j in V_e:
        if G_e.has_edge(i, j):
            model.addConstrs(t[j, m] >= t[i, m] + G_e[i][j][0]['travel_time'] + T * (x[edge_to_no[(i, j)], m] - 1) for m in truck)
model.addConstrs(t[arrival, m] == t[departure, m] + sum(G_e[i][j][0]['travel_time'] * x[edge_to_no[(i, j)], m] for i in V_e for j in V_e if G_e.has_edge(i, j))
                for m in truck)
model.addConstrs(t[departure, m] == 0 for m in truck)

## Budget of remote control
model.addConstrs(sum(u[q, :]) <= budget for q in Q)

## Time consistency of a truck being remotely controlled
for i in V_e:
    for j in V_e:
        if G_e.has_edge(i, j) and (G_e[i][j][0]['highway'] != 'primary' and G_e[i][j][0]['highway'] != 'secondary'):
            model.addConstrs(3 * u[q, m] >= alpha[q, edge_to_no[(i, j)], m] + beta[q, edge_to_no[(i, j)], m] + x[edge_to_no[(i, j)], m] - 2
                            for q in Q
                            for m in truck[: num_auto])
            model.addConstrs(t[j, m] - T * (alpha[q, edge_to_no[(i, j)], m]) <= a[q]
                            for q in Q
                            for m in truck[: num_auto])
            model.addConstrs(t[i, m] >= b[q] - T * (beta[q, edge_to_no[(i, j)], m])
                            for q in Q
                            for m in truck[: num_auto])

# Add the objective
model.setObjective(sum(x[edge_to_no[(i, j)], m] * G_e[i][j][0]['auto_cost'] for i in V_e for j in V_e for m in truck[: num_auto] if G_e.has_edge(i, j)) + 
                   sum(x[edge_to_no[(i, j)], m] * G_e[i][j][0]['non_auto_cost'] for i in V_e for j in V_e for m in truck[num_auto :] if G_e.has_edge(i, j)) +
                   y[departure, :] @ truck_cost + 
                   sum(u[q, :] @ control_cost for q in Q),
                   #* The last term by itself accounts for the extra cost of remote control
                   #* The last term can also avoid unneccesary positive u_{qm}
                   GRB.MINIMIZE)

# Solve the VRP
model.optimize()
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-04-23
# Set parameter LogFile to value "sparsification-8/sparsification_log.txt"
# Set parameter MIPFocus to value 3
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (linux64)
# Thread count: 16 physical cores, 32 logical processors, using up to 32 threads
# Optimize a model with 114563 rows, 226494 columns and 309138 nonzeros
# Model fingerprint: 0xcb6c7566
# Variable types: 576 continuous, 225918 integer (225918 binary)
# Coefficient statistics:
#   Matrix range     [4e-01, 1e+04]
#   Objective range  [1e+01, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+04]
# Presolve removed 2090 rows and 150775 columns (presolve time = 6s) ...
# Presolve removed 5381 rows and 152994 columns (presolve time = 11s) ...
# Presolve removed 5381 rows and 152994 columns
# Presolve time: 13.80s
# Presolved: 109182 rows, 73500 columns, 293588 nonzeros
# Variable types: 565 continuous, 72935 integer (72935 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Root relaxation presolve removed 367 rows and 362 columns
# Root relaxation presolved: 108815 rows, 73138 columns, 292831 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.3159047e+03   5.087057e+03   1.118450e+08     21s
#      970    4.2928676e+03   0.000000e+00   0.000000e+00     22s
#      970    4.2928676e+03   0.000000e+00   0.000000e+00     22s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#      451 DPushes remaining with DInf 0.0000000e+00                22s
#        0 DPushes remaining with DInf 0.0000000e+00                22s
#
#       94 PPushes remaining with PInf 0.0000000e+00                22s
#        0 PPushes remaining with PInf 0.0000000e+00                22s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 8.8628744e+02     22s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1489    4.2928676e+03   0.000000e+00   8.862874e+02     22s
#     1500    4.2928676e+03   0.000000e+00   0.000000e+00     22s
#     1500    4.2928676e+03   0.000000e+00   0.000000e+00     22s
# Concurrent spin time: 0.47s
#
# Solved with primal simplex
#
# Root relaxation: objective 4.292868e+03, 1500 iterations, 6.87 seconds (1.99 work units)
# Total elapsed time = 25.35s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 8031.55239    0  140          - 8031.55239      -     -   26s
#      0     0 8031.55472    0   95          - 8031.55472      -     -   39s
#      0     0 8031.55472    0  102          - 8031.55472      -     -   59s
#      0     0 8032.54735    0   85          - 8032.54735      -     -   65s
#      0     0 8032.54735    0  116          - 8032.54735      -     -   65s
#      0     0 8032.54735    0   99          - 8032.54735      -     -   72s
#      0     0 8065.59124    0  115          - 8065.59124      -     -   72s
#      0     0 8065.59124    0   93          - 8065.59124      -     -   73s
#      0     0 8065.72223    0   64          - 8065.72223      -     -   79s
#      0     0 8065.72223    0   64          - 8065.72223      -     -   80s
#      0     0 8076.49828    0  118          - 8076.49828      -     -   86s
#  11954  1182     cutoff   36      9558.73669 9498.75774  0.63%   594 1411s
#  12005   976 9500.30969   33  197 9558.73669 9499.72797  0.62%   593 1424s
#  12277   769     cutoff   27      9558.73669 9511.66560  0.49%   586 1434s
#  12545   769     cutoff   21      9558.73669 9512.73680  0.48%   579 1435s
#  12585   599 infeasible   23      9558.73669 9520.98934  0.39%   579 1440s
#  12978   347 infeasible   31      9558.73669 9534.93345  0.25%   570 1450s
#  13110   262 infeasible   26      9558.73669 9539.95132  0.20%   566 1459s
#  13204   205 infeasible   32      9558.73669 9543.68269  0.16%   564 1465s
#  13392    68 infeasible   32      9558.73669 9553.01129  0.06%   558 1470s
#
# Cutting planes:
#   Learned: 11
#   Gomory: 60
#   Lift-and-project: 7
#   Cover: 3275
#   Implied bound: 2371
#   Projected implied bound: 2
#   Clique: 4299
#   MIR: 120
#   StrongCG: 2
#   Flow cover: 3027
#   GUB cover: 12
#   Inf proof: 39
#   Zero half: 231
#   RLT: 102
#   Relax-and-lift: 2364
#
# Explored 13489 nodes (7488672 simplex iterations) in 1473.09 seconds (566.00 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 3: 9558.74 9682.74 11304.2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.558736693872e+03, best bound 9.558623653239e+03, gap 0.0012%

# %%
"""
Extract the routes (Sparse Representation)
"""

route = []
# tmp_route = [departure]

for m in truck:
    
    departure_out_edge_no = [edge_to_no[e] for e in list(G_e.out_edges(departure))]
    departure_outflow = x[departure_out_edge_no, m].X
    
    if sum(departure_outflow) == 0:
        route.append([])
        continue
    
    route_m = [new_to_old[departure]]
    i = departure
    while i != arrival:

        i_out_edges = list(G_e.out_edges(i))
        i_out_edges_no = [edge_to_no[e] for e in i_out_edges]
        i_outflow = x[i_out_edges_no, m].X
        next_edge = i_out_edges[np.where(i_outflow)[0][0]]
        next_node = next_edge[1]
        
        if next_node % len(V) != i % len(V):
            route_m.append(new_to_old[next_node % len(V)])
        i = next_node
        # if m == 1:
            # tmp_route.append(i)
    route.append(route_m)

# %%
"""
Write the routes to a json file
"""

dict_routes = dict(zip(range(len(route)), route))
with open('sparsification-' +str(example) + '/routes.json', 'w') as outfile:
    json.dump(dict_routes, outfile)

# %%
"""
Visualize all routes and output the figures 
"""


# color_list = []
# for i in range(5):
#     random_number = random.randint(0,16777215)
#     hex_number = str(hex(random_number))
#     hex_number ='#'+ hex_number[2:]
#     color_list.append(hex_number)
# print(color_list)

# Remove old figures
for figure in glob.glob("sparsification-"+str(example)+'/route-*'):
    os.remove(figure)


counter = 0
for m in range(len(route)):
    if len(route[m]) <= 1:
        counter += 1
    if len(route[m]) > 1:
        if m < num_auto:
            color = '#FFC0CB'
        else:
            color = '#00FFFF'
        ox.plot.plot_graph_route(G_s, route[m], route_color = color, route_linewidth=4,
                        route_alpha=0.5, orig_dest_size=100, figsize = (30, 30), save = True, filepath = 'sparsification-' + str(example) + '/route-' + str(m - counter + 1)+'.png')
# Out:
# /home/zh223/miniconda3/lib/python3.7/site-packages/pyproj/crs/crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /home/zh223/miniconda3/lib/python3.7/site-packages/pyproj/crs/crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /home/zh223/miniconda3/lib/python3.7/site-packages/pyproj/crs/crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /home/zh223/miniconda3/lib/python3.7/site-packages/pyproj/crs/crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /home/zh223/miniconda3/lib/python3.7/site-packages/pyproj/crs/crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /home/zh223/miniconda3/lib/python3.7/site-packages/pyproj/crs/crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
num_control = {'control_vector': list(np.sum(u.X, axis=1))}
with open('sparsification-' +str(example) + '/control.json', 'w') as outfile:
    json.dump(num_control, outfile)
